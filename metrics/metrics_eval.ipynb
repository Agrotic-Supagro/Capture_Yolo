# %%
import metrics as metrics
iou_thresholds = {
    0: 0.2,  # IoU threshold for class 0
    1: 0.1,  # IoU threshold for class 1
    2: 0.2   # IoU threshold for class 2
}

# %%
pred_metrics = metrics.metrics(predictions_dir="../results/train_corrected_novis/labels", gt1_dir="../metrics/1st_plan_evident", gt2_dir="../metrics/full_plan", iou_thresholds =iou_thresholds)
# Out:
# Class-specific - TP: {2: 120, 0: 323, 1: 0}, FP: {2: 49, 0: 16, 1: 1}, FN: {2: 31, 0: 74, 1: 0}
# Class-agnostic - TP: 459, FP: 40, FN: 86
#
# ============================================================
# DETECTION METRICS SUMMARY
# ============================================================
#
# CLASS-SPECIFIC METRICS:
# ----------------------------------------
# Class 0 (mature):
#   Precision: 0.953
#   Recall:    0.814
#   F1-Score:  0.878
#   TP/FP/FN:  323/16/74
#
# Class 1 (jeune):
#   Precision: 0.000
#   Recall:    0.000
#   F1-Score:  0.000
#   TP/FP/FN:  0/1/0
#
# Class 2 (medium):
#   Precision: 0.710
#   Recall:    0.795
#   F1-Score:  0.750
#   TP/FP/FN:  120/49/31
#
# CLASS-AGNOSTIC METRICS:
# ----------------------------------------
# Overall Detection Performance (ignoring class labels):
#   Precision: 0.920
#   Recall:    0.842
#   F1-Score:  0.879
#   TP/FP/FN:  459/40/86
#
# Note: In class-agnostic evaluation, a 'mature grape' detected as
#       'medium grape' is still considered a correct detection.
# ============================================================
